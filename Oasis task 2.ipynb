# %% [markdown]
# ### UNEMPLOYMENT ANALYSIS WITH PYTHON

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Uploading 2 Datasets
#
# Unemployment rate upto 2020 dataset
#
# Unemployment in India dataset

# %%
df1=pd.read_csv(r"C:\Users\Akshata Potdar\Downloads\archive (2)\Unemployment in India.csv")
df1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 763                  NaN                                       NaN    NaN
# 764                  NaN                                       NaN    NaN
# 765                  NaN                                       NaN    NaN
# 766                  NaN                                       NaN    NaN
# 767                  NaN                                       NaN    NaN
#
# [768 rows x 7 columns]

# %%
df2=pd.read_csv(r"C:\Users\Akshata Potdar\Downloads\archive (2)\Unemployment_Rate_upto_11_2020.csv")
df2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]

# %% [markdown]
# *Random 10 rows of "Unemployment rate upto 2020 dataset"*

# %%
df1.sample(10)
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 68             Goa   31-05-2019    Monthly                              2.91
# 69             Goa   30-06-2019    Monthly                              5.45
# 258      Rajasthan   30-06-2019    Monthly                             13.70
# 153      Karnataka   30-11-2019    Monthly                              1.19
# 463            Goa   31-01-2020    Monthly                             10.92
# 399          Assam   31-05-2020    Monthly                             10.77
# 478        Gujarat   30-04-2020    Monthly                             25.94
# 712  Uttar Pradesh   31-05-2019    Monthly                             14.40
# 469        Gujarat   31-07-2019    Monthly                              5.15
# 647      Rajasthan   31-08-2019    Monthly                             14.71
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 68              179340.0                                     39.16  Rural
# 69              170471.0                                     38.19  Rural
# 258           14610564.0                                     41.02  Rural
# 153           11537217.0                                     36.45  Rural
# 463             257814.0                                     35.95  Urban
# 399            1441722.0                                     39.04  Urban
# 478            6701284.0                                     36.33  Urban
# 712           13391244.0                                     40.43  Urban
# 469            9828023.0                                     42.54  Urban
# 647            5195170.0                                     40.34  Urban

# %% [markdown]
# Random 10 rows of "Unemployment in India dataset"

# %%
df2.sample(10)
# Out:
#               Region         Date  Frequency  \
# 248      Uttarakhand   29-02-2020          M
# 104        Jharkhand   30-06-2020          M
# 101        Jharkhand   31-03-2020          M
# 263      West Bengal   31-07-2020          M
# 180           Punjab   29-02-2020          M
# 194        Rajasthan   30-06-2020          M
# 183           Punjab   31-05-2020          M
# 51               Goa   29-02-2020          M
# 95   Jammu & Kashmir   31-07-2020          M
# 58               Goa   30-09-2020          M
#
#       Estimated Unemployment Rate (%)   Estimated Employed  \
# 248                              4.99              3020931
# 104                             20.95              8622722
# 101                              8.23              9638115
# 263                              6.83             35372506
# 180                             10.97              9229047
# 194                             14.39             20506612
# 183                             28.33              6872938
# 51                               2.81               478068
# 95                              10.88              3558889
# 58                              15.38               425004
#
#       Estimated Labour Participation Rate (%) Region.1  longitude  latitude
# 248                                     36.48    North    30.0668   79.0193
# 104                                     40.59     East    23.6102   85.2799
# 101                                     39.34     East    23.6102   85.2799
# 263                                     46.17     East    22.9868   87.8550
# 180                                     41.72    North    31.1471   75.3412
# 194                                     41.38    North    27.0238   74.2179
# 183                                     38.39    North    31.1471   75.3412
# 51                                      38.38     West    15.2993   74.1240
# 95                                      38.03    North    33.7782   76.5762
# 58                                      38.89     West    15.2993   74.1240

# %% [markdown]
# Top and bottom 5 rows of "Unemployment rate upto 2020 dataset"

# %%
df1.head(5)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df1.tail(5)
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %% [markdown]
# Top and bottom 4 rows of "Unemployment in India dataset"

# %%
df2.head(5)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74
# 4    15.9129     79.74

# %%
df2.tail(5)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855

# %% [markdown]
# Total rows and columns in dataset in both datasets

# %%
df1.shape
# Out:
# (768, 7)

# %%
df2.shape
# Out:
# (267, 9)

# %% [markdown]
# Names of columns in both datasets

# %%
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ##### Datasets information

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %% [markdown]
# For Checking NULL values in both datasets

# %%
print("Total NULL values =\n\n",df1.isnull().sum())
# Out:
# Total NULL values =
#
#  Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
print("Total NULL values =\n\n",df2.isnull().sum())
# Out:
# Total NULL values =
#
#  Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
print("Size of dataset is: ",df1.size)
# Out:
# Size of dataset is:  5376

# %%
print("Size of dataset is: ",df2.size)
# Out:
# Size of dataset is:  2403

# %% [markdown]
# *Description of both datasets*

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 763                  NaN                                       NaN    NaN
# 764                  NaN                                       NaN    NaN
# 765                  NaN                                       NaN    NaN
# 766                  NaN                                       NaN    NaN
# 767                  NaN                                       NaN    NaN
#
# [768 rows x 7 columns]>

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]>

# %% [markdown]
# #### *Null Value counts in both datasets*

# %%
df1.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Area
# False   False  False       False                             False                False                                     False    740
# True    True   True        True                              True                 True                                      True      28
# dtype: int64

# %%
df2.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  longitude  latitude
# False   False  False       False                             False                False                                     False     False      False       267
# dtype: int64

# %% [markdown]
# #### HEAT MAP

# %% [markdown]
# *For "Unemployment_Rate_upto_11_2020" dataset*

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sns.heatmap(df1.corr(), annot=True, cmap="viridis").set(title='\n\nHeatmap of Correlated values for "Unemployment_Rate_upto_11_2020" \n\n')
plt.show()

# %% [markdown]
# *For "Unemployment_in_india" dataset*

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sns.heatmap(df2.corr(), annot=True, cmap="viridis").set(title='\n\nHeatmap of Correlated values for "Unemployment_Rate_upto_11_2020" \n\n')
plt.show()

# %% [markdown]
# *PIE PLOTS*

# %% [markdown]
# *PARTITION ACCORDING TO AREA on "Unemployment in india" dataset*

# %%
fig, ax = plt.subplots(figsize =(8, 7))
#labels
m=['Rural','Urban']
#title for chart
ax.set_title("\nPARTITION ACCORDING TO AREA IN \"Unemployment in india\" dataset",color="brown")
# Creating color parameters
colors = ( "blue" ,"magenta")
# Creating explode data
explode = (0.2, 0.0)
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
# Creating plot
wedges, texts, autotexts = ax.pie(df1['Area'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = m,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 105,
                                  wedgeprops = wp,
                                  textprops = dict(color ="brown"))
# Adding legend
ax.legend(wedges,m,
          title ="AREA",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")

plt.show()

# %%
fig, ax = plt.subplots(figsize =(8, 7))
#labels
m=['South', 'Northeast', 'East', 'West', 'North']
#title for chart
ax.set_title("\nPARTITION ACCORDING TO REGION DIRECTIONS",color="brown")
# Creating color parameters
colors = ( "orange", "cyan", "brown","grey", "indigo")
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0)
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
# Creating plot
wedges, texts, autotexts = ax.pie(df2['Region.1'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = m,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
# Adding legend
ax.legend(wedges,m,
          title ="Directions",
          loc ="center left",
          bbox_to_anchor =(1.2, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")

plt.show()

# %% [markdown]
# #### LINE PLOTS on
# #### Unemployment_Rate_upto_11_2020 Dataset

# %% [markdown]
# Unemployment according to Dates in different Regions Directions

# %% [markdown]
# * Estimated Labour Participation Rate

# %%
fig = plt.figure(figsize = (9, 6))
sns.lineplot(y=' Estimated Unemployment Rate (%)', data=df2, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Estimated Unemployment Rate (%)

# %%
fig = plt.figure(figsize = (9, 7))
sns.lineplot(y=' Estimated Labour Participation Rate (%)', data=df2, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Estimated Employed

# %%
fig = plt.figure(figsize = (9, 7))
sns.lineplot(y=' Estimated Labour Participation Rate (%)', data=df2, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Estimated Labour Participation Rate

# %%
fig = plt.figure(figsize = (9, 6))
sns.lineplot(y=' Estimated Employed', data=df2, x=' Date',hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### HISTOGRAM GRAPHICAL REPRESENTATIONS

# %% [markdown]
# *Unemployment_Rate_upto_11_2020 Dataset*

# %%
df1.hist(bins=200,figsize=[15,8])
plt.show()

# %% [markdown]
# *Unemployment_in_India Dataset*

# %%
df2.hist(bins=200,figsize=[10,8])
plt.show()

# %% [markdown]
# ### PAIR PLOTS

# %% [markdown]
# *For "Unemployment_Rate_upto_11_2020" dataset*

# %%
sns.pairplot(df1,height=2.7, aspect=1.5,diag_kws={'color':'red'},plot_kws={'color':'green'})
plt.show()

# %% [markdown]
# *For "Unemployment in india" dataset*

# %%
sns.pairplot(df2,height=4,diag_kws={'color':'red', 'bins':5})
plt.show()

# %% [markdown]
# #### LINE GRAPH on "Unemployment in india" dataset
#
# GRAPH FOR ESTIMATED EMPLOYED IN INDIA

# %%
plt.figure(figsize=(20, 5))
plt.plot(df2[' Estimated Employed'],color='green')
plt.xlabel('Estimated Employed')
plt.xlabel('Count')
plt.title('India Employed Statistics')
plt.show()

# %% [markdown]
# *GRAPH FOR Estimated Labour Participation Rate IN INDIA*

# %%
plt.figure(figsize=(20, 5))
plt.plot(df2[' Estimated Labour Participation Rate (%)'],color='orange')
plt.xlabel('Estimated Labour Participation Rate (%)')
plt.xlabel('Count')
plt.title('India Labour Participation Statistics')
plt.show()

# %% [markdown]
# *GRAPH FOR Estimated Unemployment Rate IN INDIA*

# %%
plt.figure(figsize=(20, 5))
plt.plot(df2[' Estimated Unemployment Rate (%)'],color='magenta')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.xlabel('Count')
plt.title('India Unemployment Statistics')
plt.show()

# %% [markdown]
# ### FINAL DISPLAY OF THE UNEMPLOYMENT RATE IN INDIA  (red line) AND SPECIFICALLY IN 2020 IN INDIA (blue line)

# %%
fig = plt.figure(figsize = (20, 8))
ax= sns.lineplot(y=' Estimated Unemployment Rate (%)', x='Region', data=df1)
ax1 = sns.lineplot(y=' Estimated Unemployment Rate (%)', x='Region', data=df2)
plt.xticks(rotation=40)
plt.show()
